# %%
import duckdb

with duckdb.connect("data/sakila.duckdb") as conn:
    actor = conn.sql("from staging.actor;").df()
    film = conn.sql("from staging.film;").df()

# %%
import duckdb

conn = duckdb.connect("data/sakila.duckdb") #opening the connection 
conn.sql("SET search_path='staging';")
conn.sql("""

""").df # sql queries

# you can just send in the sql queries since the conn is open.

#conn.close() - to close the conn

# %%
import duckdb

def query_sakila(query: str, duckdb_path = "data/sakila.duckdb"):
    with duckdb.connect(duckdb_path) as conn:
        df = conn.sql(query=query).df()

    return df

# this method will open and close everytime you call the function
# you could send in sql queries by using the function as follows:

query_sakila("""

""").head()
