# %% [markdown]
# # Connect duckdb

# %%
import duckdb

with duckdb.connect("databases/hotels.duckdb") as conn:
    conn.sql("DROP TABLE IF EXISTS bookings;")
    conn.sql(
        """
        CREATE OR REPLACE TABLE bookings (
            date DATE, 
            room_type STRING,
            price FLOAT,
            breakfast BOOLEAN,
            name STRING,
            email STRING,
            guests UINT8
        )
    """
    )


    conn.sql("""
    INSERT INTO bookings VALUES
        ('2024-01-15', 'Single', 150.00, True, 'John Doe', 'john@email.com', 2),
        ('2024-01-16', 'Double', 220.00, False, 'Jane Smith', 'jane@email.com', 3),
        ('2024-01-17', 'Suite', 450.00, True, 'Bob Johnson', 'bob@email.com', 1),
        ('2024-01-18', 'Single', 150.00, True, 'Alice Brown', 'alice@email.com', 1),
        ('2024-01-19', 'Double', 220.00, True, 'Charlie Davis', 'charlie@email.com', 4),
        ('2024-01-20', 'Suite', 450.00, False, 'Eva Wilson', 'eva@email.com', 2),
        ('2024-01-21', 'Single', 150.00, False, 'Frank Miller', 'frank@email.com', 1),
        ('2024-01-22', 'Double', 220.00, True, 'Grace Lee', 'grace@email.com', 3);
    """)


    bookings = conn.sql("FROM bookings;").df()

    
bookings
# Out:
#         date room_type  price  breakfast           name              email  \
# 0 2024-01-15    Single  150.0       True       John Doe     john@email.com
# 1 2024-01-16    Double  220.0      False     Jane Smith     jane@email.com
# 2 2024-01-17     Suite  450.0       True    Bob Johnson      bob@email.com
# 3 2024-01-18    Single  150.0       True    Alice Brown    alice@email.com
# 4 2024-01-19    Double  220.0       True  Charlie Davis  charlie@email.com
# 5 2024-01-20     Suite  450.0      False     Eva Wilson      eva@email.com
# 6 2024-01-21    Single  150.0      False   Frank Miller    frank@email.com
# 7 2024-01-22    Double  220.0       True      Grace Lee    grace@email.com
#
#    guests
# 0       2
# 1       3
# 2       1
# 3       1
# 4       4
# 5       2
# 6       1
# 7       3

# %%
bookings.head()
# Out:
#         date room_type  price  breakfast           name              email  \
# 0 2024-01-15    Single  150.0       True       John Doe     john@email.com
# 1 2024-01-16    Double  220.0      False     Jane Smith     jane@email.com
# 2 2024-01-17     Suite  450.0       True    Bob Johnson      bob@email.com
# 3 2024-01-18    Single  150.0       True    Alice Brown    alice@email.com
# 4 2024-01-19    Double  220.0       True  Charlie Davis  charlie@email.com
#
#    guests
# 0       2
# 1       3
# 2       1
# 3       1
# 4       4

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       8 non-null      datetime64[us]
#  1   room_type  8 non-null      object
#  2   price      8 non-null      float32
#  3   breakfast  8 non-null      bool
#  4   name       8 non-null      object
#  5   email      8 non-null      object
#  6   guests     8 non-null      uint8
# dtypes: bool(1), datetime64[us](1), float32(1), object(3), uint8(1)
# memory usage: 432.0+ bytes

# %% [markdown]
# ## Read csv file directly

# %%
invoice = duckdb.sql ("""
    FROM 'data/Leverantorsfaktura202408.csv';
""").df()

invoice.head()

invoice.info
# Out:
# <bound method DataFrame.info of                   Förvaltning                          Leverantör  \
# 0           Stadsmiljönämnden                      TRACK TEC GMBH
# 1        Kretslopp och Vatten  POLISMYNDIGHETEN I VÄSTRA GÖTALAND
# 2        Kretslopp och Vatten  POLISMYNDIGHETEN I VÄSTRA GÖTALAND
# 3        Kretslopp och Vatten  POLISMYNDIGHETEN I VÄSTRA GÖTALAND
# 4        Exploateringsnämnden  POLISMYNDIGHETEN I VÄSTRA GÖTALAND
# ...                       ...                                 ...
# 92984       Stadsmiljönämnden                             VIANOVA
# 92985       Stadsmiljönämnden                             VIANOVA
# 92986  Stadsfastighetsnämnden                    WINDOWMASTER A/S
# 92987  Stadsfastighetsnämnden                    WINDOWMASTER A/S
# 92988           Kulturnämnden             WÄRTSILA VOYAGE LIMITED
#
#       Organisationsnummer  Verifikationsnummer  Konto  \
# 0           106/5727/0626           4001291513   4101
# 1              2021000076           5601378982   6185
# 2              2021000076           5601377374   6185
# 3              2021000076           5601378519   6185
# 4              2021000076           2001226894   7641
# ...                   ...                  ...    ...
# 92984              SAKNAS           4001295782   7432
# 92985              SAKNAS           4001290661   7432
# 92986              SAKNAS           2302185009   6151
# 92987              SAKNAS           2302185009   2677
# 92988              SAKNAS           6901236169   7611
#
#                                            Kontotext Belopp exkl moms
# 0           Inköp anläggnings och underhållsmaterial     9 835 315,00
# 1                             Anläggningsentreprenad           870,00
# 2                             Anläggningsentreprenad           870,00
# 3                             Anläggningsentreprenad           870,00
# 4            Diverse skatter och offentliga avgifter         1 000,00
# ...                                              ...              ...
# 92984                                    IT tjänster      -263 400,00
# 92985                                    IT tjänster       263 400,00
# 92986        Mindre reparation o underhåll fastighet        23 518,07
# 92987  Beräknad utg moms tjänsteinköp i Sverige, 25%        -5 879,52
# 92988                                       Avgifter        45 288,75
#
# [92989 rows x 7 columns]>

# %%
finance = duckdb.sql("""
    FROM 'data/financial_data.csv';
""").df()

finance.head()
# Out:
#   transaction_id       date             company transaction_type  \
# 0        TXN1000 2024-01-15  UnitedHealth Group       Investment
# 1        TXN1001 2024-12-22        Broadcom Inc          Expense
# 2        TXN1002 2024-10-11           Starbucks     Capital Gain
# 3        TXN1003 2024-09-30     Lockheed Martin         Dividend
# 4        TXN1004 2024-07-02            IBM Corp   Operating Cost
#
#          category     amount currency account_number  \
# 0       Marketing  498789.60      JPY       ACC90616
# 1  Administrative  407890.44      GBP       ACC72475
# 2      Operations  363927.61      USD       ACC26222
# 3             R&D  336378.01      EUR       ACC86805
# 4  Administrative  193284.51      GBP       ACC72617
#
#                      description     status payment_method  tax_amount  \
# 0             Q1 revenue for r&d  Completed          Check    15640.11
# 1         Q4 capital gain for it  Completed  Wire Transfer    25883.85
# 2  Q3 expense for administrative    Pending            ACH    24814.56
# 3    Q4 investment for marketing  Completed          Check    46359.17
# 4    Q2 expense for distribution  Completed    Credit Card    41529.35
#
#    net_amount
# 0   483149.49
# 1   382006.59
# 2   339113.05
# 3   290018.84
# 4   151755.16

# %% [markdown]
# ## Read several csv files and combine

# %%
hotels = duckdb.sql("""
    FROM 'data/hotel*.csv';
""").df()

hotels.sample(10)
# Out:
#       booking_id       guest_name   check_in  check_out room_type  guests  \
# 8   H2025-02-009   Olivia Larsson 2025-02-18 2025-02-20  Standard       2
# 2   H2025-01-003       Sofia Lind 2025-01-14 2025-01-16    Deluxe       2
# 6   H2025-02-007   Elin Andersson 2025-02-07 2025-02-09    Deluxe       2
# 3   H2025-01-004    Erik Svensson 2025-01-20 2025-01-22  Standard       3
# 4   H2025-01-005  Maria Johansson 2025-01-27 2025-01-28    Single       1
# 10  H2025-03-011       Maria Berg 2025-03-21 2025-03-22  Standard       3
# 9   H2025-02-010   Viktor Persson 2025-02-24 2025-02-26    Deluxe       3
# 7   H2025-02-008   Lukas Eriksson 2025-02-12 2025-02-13    Single       1
# 11  H2025-03-012    Isak Axelsson 2025-03-15 2025-03-18    Single       1
# 14  H2025-03-015   Albin Lundberg 2025-03-01 2025-03-03    Single       1
#
#     price_sek_per_night  breakfast       source     status
# 8                  1210       True       Direct  Confirmed
# 2                  1450       True      Expedia  Confirmed
# 6                  1520       True  Booking.com  Confirmed
# 3                  1250       True       Direct  Confirmed
# 4                   920      False   Hotels.com  Cancelled
# 10                 1250       True   Hotels.com  Confirmed
# 9                  1580       True   Hotels.com  Confirmed
# 7                   940      False      Expedia  Confirmed
# 11                 1012       True       Direct  Confirmed
# 14                 1027      False      Expedia  Confirmed

# %% [markdown]
# ## Read json data

# %%
duckdb.sql("FROM 'data/library.json';").df()
# Out:
#             name                                              books
# 0  Coolu Libraru  [{'id': 1, 'title': 'The Hitchhiker's Guide to...

# %% [markdown]
# ### Unnesting

# %%
books_df = duckdb.sql("""
           SELECT
           l.name as library_name,
           UNNEST(l.books, max_depth:= 2)
           FROM 'data/library.json' AS l;""").df()

books_df
# Out:
#     library_name  id                                 title  \
# 0  Coolu Libraru   1  The Hitchhiker's Guide to the Galaxy
# 1  Coolu Libraru   2                   Pride and Prejudice
# 2  Coolu Libraru   3                                  1984
# 3  Coolu Libraru   4                 To Kill a Mockingbird
# 4  Coolu Libraru   5                      The Great Gatsby
# 5  Coolu Libraru   6                             Moby Dick
# 6  Coolu Libraru   7                         War and Peace
# 7  Coolu Libraru   8                 The Lord of the Rings
# 8  Coolu Libraru   9                  Crime and Punishment
# 9  Coolu Libraru  10                           Don Quixote
#
#                 author  year
# 0        Douglas Adams  1979
# 1          Jane Austen  1813
# 2        George Orwell  1949
# 3           Harper Lee  1960
# 4  F. Scott Fitzgerald  1925
# 5      Herman Melville  1851
# 6          Leo Tolstoy  1869
# 7       J.R.R. Tolkien  1954
# 8    Fyodor Dostoevsky  1866
# 9  Miguel de Cervantes  1605

# %% [markdown]
# ## use cross join

# %%
duckdb.sql("""
    SELECT 
        l.name,
        b
    FROM 'data/library.json' l
    CROSS JOIN UNNEST(l.books) b
""").df()
# Out:
#             name                                                  b
# 0  Coolu Libraru  {'unnest': {'id': 10, 'title': 'Don Quixote', ...
# 1  Coolu Libraru  {'unnest': {'id': 9, 'title': 'Crime and Punis...
# 2  Coolu Libraru  {'unnest': {'id': 8, 'title': 'The Lord of the...
# 3  Coolu Libraru  {'unnest': {'id': 7, 'title': 'War and Peace',...
# 4  Coolu Libraru  {'unnest': {'id': 6, 'title': 'Moby Dick', 'au...
# 5  Coolu Libraru  {'unnest': {'id': 5, 'title': 'The Great Gatsb...
# 6  Coolu Libraru  {'unnest': {'id': 4, 'title': 'To Kill a Mocki...
# 7  Coolu Libraru  {'unnest': {'id': 3, 'title': '1984', 'author'...
# 8  Coolu Libraru  {'unnest': {'id': 2, 'title': 'Pride and Preju...
# 9  Coolu Libraru  {'unnest': {'id': 1, 'title': 'The Hitchhiker'...

# %%
duckdb.sql("""
    SELECT 
        l.name,
        b.unnest.title,
        b.unnest.author,
        b.unnest.year,
    FROM 'data/library.json' l
    CROSS JOIN UNNEST(l.books) b
""").df()
# Out:
#             name                                 title               author  \
# 0  Coolu Libraru                           Don Quixote  Miguel de Cervantes
# 1  Coolu Libraru                  Crime and Punishment    Fyodor Dostoevsky
# 2  Coolu Libraru                 The Lord of the Rings       J.R.R. Tolkien
# 3  Coolu Libraru                         War and Peace          Leo Tolstoy
# 4  Coolu Libraru                             Moby Dick      Herman Melville
# 5  Coolu Libraru                      The Great Gatsby  F. Scott Fitzgerald
# 6  Coolu Libraru                 To Kill a Mockingbird           Harper Lee
# 7  Coolu Libraru                                  1984        George Orwell
# 8  Coolu Libraru                   Pride and Prejudice          Jane Austen
# 9  Coolu Libraru  The Hitchhiker's Guide to the Galaxy        Douglas Adams
#
#    year
# 0  1605
# 1  1866
# 2  1954
# 3  1869
# 4  1851
# 5  1925
# 6  1960
# 7  1949
# 8  1813
# 9  1979

# %%
books_df.to_csv("data/books.csv")
